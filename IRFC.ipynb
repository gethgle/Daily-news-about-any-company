# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import time
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import Select
#import org.openqa.selenium.Keys
from random import randint
from time import sleep
import tldextract
from selenium.common.exceptions import NoSuchElementException

import pandas as pd
import logging

# %%
drive_path = r"C:\Users\shankar\Desktop\projects\chromedriver.exe"
# keep clicking untill no click buttion
URL = 'https://www.tickertape.in/'
chrome_options = webdriver.ChromeOptions();
#chrome_options.add_argument("start-maximized")
#chrome_options.add_argument("disable-infobars")
#chrome_options.add_argument("--disable-extensions") 
chrome_options.add_argument("user-agent= Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36")
chrome_options.add_experimental_option("excludeSwitches", ['enable-automation']);

# %%
def news_tracker(url,drive_path,stock):
    # get https://www.tickertape.in/ web page
    def basic_url(url):
        chrome_options = webdriver.ChromeOptions();
        chrome_options.add_experimental_option("excludeSwitches", ['enable-automation']);
        driver= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
        driver.get(url)
        sleep(randint(3,5))
        return driver
    base_driver = basic_url(URL) 
    
    ########################
    # serch for compeny stockes
    def search_key(word,driver):
        search= driver.find_element_by_id("search-stock-input").send_keys(word) 
        sleep(randint(1,4))
        act = ActionChains(driver)
        act.send_keys(Keys.ENTER).perform()
        sleep(randint(2,5))
        driver.find_element_by_link_text('News').click()
        sleep(randint(1,4))
        driver.find_element_by_class_name('suggestion-wrapper').click()
        driver.find_element_by_xpath('//*[@id="menu-items-list"]/ul/div[2]').click()
        return driver
    
    search_drive = search_key(stock,base_driver)
    
    #news_urls = search_drive.find_elements_by_xpath("//div[@data-section-tag='latestNews'or @data-section-tag='olderNews']/div/a")
    #for url in news_urls:
        #sours= url.find_element_by_xpath(".//div[2]/p/span[3]").text 
    return search_drive

# %%
search_drive = news_tracker(URL,drive_path,'Reliance Industries')
sleep(randint(1,5))
while True:
    sleep(randint(1,5))
    try:
        load_more = search_drive.find_element_by_xpath('//*[@id="load-more"]/button').click()
    except NoSuchElementException:
        break
news_urls = search_drive.find_elements_by_xpath("//div[@data-section-tag='latestNews'or @data-section-tag='olderNews']/div/a")

# %%
len(news_urls)
# Out:
# 3310

# %%
news_urls[5].get_property('href')
# Out:
# 'https://www.businesstoday.in/markets/company-stock/stocks-to-watch-today-on-march-24-reliance-airtel-ongc-hero-motocorp-rail-vikas-nigam-tata-motors/story/434704.html'

# %%
news_link =[]
for i in news_urls:
    link= i.get_property('href')
    ele = i
    ele_details = {'links':link,'ele':ele}
    news_link.append(ele_details)

# %%
news_urls_df = pd.DataFrame(news_link)

# %%
news_urls_df.head()
# Out:
#                                                links  \
# 0  https://www.news18.com/news/business/sensex-si...
# 1  https://www.livemint.com/market/stock-market-n...
# 2  https://www.freepressjournal.in/business/marke...
# 3  https://www.business-standard.com/podcast/mark...
# 4  https://www.freepressjournal.in/business/sense...
#
#                                                  ele
# 0  <selenium.webdriver.remote.webelement.WebEleme...
# 1  <selenium.webdriver.remote.webelement.WebEleme...
# 2  <selenium.webdriver.remote.webelement.WebEleme...
# 3  <selenium.webdriver.remote.webelement.WebEleme...
# 4  <selenium.webdriver.remote.webelement.WebEleme...

# %%
exe_df = pd.read_csv('reliance_df_2.CSV')

# %%
exe_df.head()
# Out:
#                                            headlines             sources  \
# 0  Sensex Sinks Over 400 Points in Early Trade; N...              News18
# 1  Indian equity markets sink 1% as covid cases s...            Livemint
# 2  Market down in early trade: IndusInd Bank, Mar...  Free Press Journal
# 3  Market Wrap, March 24: Here’s all that happene...   Business Standard
# 4  Sensex tumbles over 300 points in early trade;...  Free Press Journal
#
#                                                links  \
# 0  https://www.news18.com/news/business/sensex-si...
# 1  https://www.livemint.com/market/stock-market-n...
# 2  https://www.freepressjournal.in/business/marke...
# 3  https://www.business-standard.com/podcast/mark...
# 4  https://www.freepressjournal.in/business/sense...
#
#                                        date  \
# 0  LAST UPDATED:\nMARCH 25, 2021, 10:37 IST
# 1        Updated: 25 Mar 2021, 10:13 AM IST
# 2  : Thursday, March 25, 2021, 10:06 AM IST
# 3
# 4  : Wednesday, March 24, 2021, 9:54 AM IST
#
#                                           news_story
# 0  Equity benchmark Sensex dropped over 400 point...
# 1  Index heavyweights Infosys, Reliance Industrie...
# 2  Equity benchmark Sensex dropped over 400 point...
# 3
# 4  Mumbai: Equity benchmark Sensex dropped over 3...

# %%
exe_df['date'] = exe_df.date.replace('\\n','', regex=True)
exe_df['date'] = exe_df.date.replace('IST','', regex=True)

# %%
exe_df.head(60)
# Out:
#                                             headlines                 sources  \
# 0   Sensex Sinks Over 400 Points in Early Trade; N...                  News18
# 1   Indian equity markets sink 1% as covid cases s...                Livemint
# 2   Market down in early trade: IndusInd Bank, Mar...      Free Press Journal
# 3   Market Wrap, March 24: Here’s all that happene...       Business Standard
# 4   Sensex tumbles over 300 points in early trade;...      Free Press Journal
# 5   Stock in news: Reliance, Airtel, ONGC, Hero Mo...          Business Today
# 6   Market Ahead, March 24: Top factors that could...       Business Standard
# 7   RIL, banks drag Sensex 871 pts lower at 49,180...       Business Standard
# 8   Saudi Aramco hints talks are on with RIL for O...       Business Standard
# 9   Bank rally gives Sensex 280-pt lift to get pas...          Economic Times
# 10  Sensex Ends 280 Points Higher, Nifty Tops 14,8...                  News18
# 11  Sensex ends 280 points higher; Nifty 50 tops 1...      Free Press Journal
# 12   Sensex ends 280 points higher; Nifty tops 14,800  The Hindu Businessline
# 13  Sensex surges over 300 pts in early trade: Ind...      Free Press Journal
# 14  How Amazon is fighting door to door to beat Mu...          Economic Times
# 15  Sensex stages 500-pt recovery, ends 87 pts low...          Economic Times
# 16  Sensex Ends 87 Points Lower; Financial Stocks ...                  News18
# 17  ‘Reliance Retail already worth $100 bn’: Jeffe...       Financial Express
# 18   Benchmarks decline; healthcare stocks buck trend       Business Standard
# 19  Stock in news: Future Retail, RIL, TCS, Airtel...          Business Today
# 20  Decline in banks outweighs gains in IT, pharma...       Business Standard
# 21  Reliance affiliate picks 3/4th of gas from own...       Business Standard
# 22  Future Group moves division bench of Delhi Hig...      Free Press Journal
# 23  Market HIGHLIGHTS: Sensex ends at fresh record...       Financial Express
# 24  Share Market Highlights: Sensex ends 316 pts h...       Financial Express
# 25  Sensex rallies over 300 pts in early trade; Re...               The Hindu
# 26  US investment firm KKR to invest Rs 5,500 cror...               Firstpost
logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)

formatter = logging.Formatter('%(levelname)s:%(name)s:%(message)s')

file_handler = logging.FileHandler('url_data.log')
file_handler.setLevel(logging.ERROR)
file_handler.setFormatter(formatter)

stream_handler = logging.StreamHandler()
stream_handler.setFormatter(formatter)

logger.addHandler(file_handler)
logger.addHandler(stream_handler)


dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)

Error_url =[]
news_data = []
for url in nwe_link.ele:
    headline = url.find_element_by_xpath(".//div[2]/h5/p").text
    sours= url.find_element_by_xpath(".//div[2]/p/span[3]").text
    link = url.get_property('href')
    try:
        if sours == "Economic Times":
            news_day,news = Economic_Times(link)
        elif sours == "Business Standard":
            news_day,news= Business_Standard(link)
        elif sours == "The Hindu Businessline":
            news_day,news= Hindu_Businessline(link)
        elif sours == "Business Today":
            news_day,news= Business_Today(link)
        elif sours == "Moneycontrol":
            news_day,news= Moneycontrol(link)
        elif sours == "Free Press Journal":
            news_day,news= Free_Press_Journal(link) 
        elif sours == "Free Press Journal":
            news_day,news= Free_Press_Journal(link)
        elif sours == "Livemint":
            news_day,news= Livemint(link)
        elif sours == "Financial Express":
            news_day,news= Financial_Express(link)
        elif sours == "India Infoline":
            news_day,news= India_Infoline(link)
        elif sours == "Firstpost":
            news_day,news= Firstpost(link)
        elif sours == "News18":
            news_day,news= News18(link)
        elif sours == "Bloomberg Quint":
            news_day,news= Bloomberg_Quint(link)
        elif sours == "The Hindu":
            news_day,news= The_Hindu(link)
        elif sours == "Investing.com":
            news_day,news= Investing_com(link)
        elif sours == "Reuters":
            news_day,news= Reuters(link)
        elif sours == "Hindustan Times":
            news_day,news=Hindustan_Times(link)
        elif sours == "Zee News":
            news_day,news=zeenews(link)
        elif sours == "Newswire":
            sour = tldextract.extract(link)
            if sour == 'freepressjournal':
                news_day,news= Free_Press_Journal(link)
            elif: sour == 'reuters':
                news_day,news= Reuters(link)
            elif: sour == 'indiainfoline':
                news_day,news= India_Infoline(link)
            elif: sour == 'india':
                news_day,news= zeenews(link)
            else:
                news_day = 'NO date'
                news =    'NO News'
        else:
            news_day = 'NO date'
            news =    'NO News'
    except:
        error_details = {'headlines':headline,'sources':sours,'links':link} 
        Error_url.append(error_details)
        
        logger.exception('no such element Unable to locate element')
        
        continue
    else:
        details = {'headlines':headline,'sources':sours,'links':link,'date':news_day,'news_story':news }
        news_data.append(details)
dri.close()
# Out:
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 48, in <module>
#     news_day,news= Bloomberg_Quint(link)
#   File "<ipython-input-51-5c0255772f00>", line 13, in Bloomberg_Quint
#     return news_day,news
# UnboundLocalError: local variable 'news_day' referenced before assignment
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 48, in <module>
#     news_day,news= Bloomberg_Quint(link)
#   File "<ipython-input-51-5c0255772f00>", line 13, in Bloomberg_Quint
#     return news_day,news
# UnboundLocalError: local variable 'news_day' referenced before assignment
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 48, in <module>
#     news_day,news= Bloomberg_Quint(link)
#   File "<ipython-input-51-5c0255772f00>", line 13, in Bloomberg_Quint
#     return news_day,news
# UnboundLocalError: local variable 'news_day' referenced before assignment
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 38, in <module>
#     news_day,news= Livemint(link)
#   File "<ipython-input-45-0d574c53b776>", line 9, in Livemint
#     news_2 = dri.find_element_by_xpath("//*[contains(@id,'mainArea')]/div[1]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'mainArea')]/div[1]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 38, in <module>
#     news_day,news= Livemint(link)
#   File "<ipython-input-45-0d574c53b776>", line 9, in Livemint
#     news_2 = dri.find_element_by_xpath("//*[contains(@id,'mainArea')]/div[1]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'mainArea')]/div[1]"}
#   (Session info: chrome=89.0.4389.90)
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 38, in <module>
#     news_day,news= Livemint(link)
#   File "<ipython-input-45-0d574c53b776>", line 9, in Livemint
#     news_2 = dri.find_element_by_xpath("//*[contains(@id,'mainArea')]/div[1]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'mainArea')]/div[1]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 48, in <module>
#     news_day,news= Bloomberg_Quint(link)
#   File "<ipython-input-51-5c0255772f00>", line 13, in Bloomberg_Quint
#     return news_day,news
# UnboundLocalError: local variable 'news_day' referenced before assignment
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 48, in <module>
#     news_day,news= Bloomberg_Quint(link)
#   File "<ipython-input-51-5c0255772f00>", line 13, in Bloomberg_Quint
#     return news_day,news
# UnboundLocalError: local variable 'news_day' referenced before assignment
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 48, in <module>
#     news_day,news= Bloomberg_Quint(link)
#   File "<ipython-input-51-5c0255772f00>", line 13, in Bloomberg_Quint
#     return news_day,news
# UnboundLocalError: local variable 'news_day' referenced before assignment
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 38, in <module>
#     news_day,news= Livemint(link)
#   File "<ipython-input-45-0d574c53b776>", line 7, in Livemint
#     news_day = dri.find_element_by_xpath("//*[contains(@id,'tBox')]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'tBox')]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 38, in <module>
#     news_day,news= Livemint(link)
#   File "<ipython-input-45-0d574c53b776>", line 7, in Livemint
#     news_day = dri.find_element_by_xpath("//*[contains(@id,'tBox')]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'tBox')]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 38, in <module>
#     news_day,news= Livemint(link)
#   File "<ipython-input-45-0d574c53b776>", line 7, in Livemint
#     news_day = dri.find_element_by_xpath("//*[contains(@id,'tBox')]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'tBox')]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 46, in <module>
#     news_day,news= News18(link)
#   File "<ipython-input-50-a457a39ab5b3>", line 6, in News18
#     news_day = dri.find_element_by_xpath('//*[@id="left"]/div[position()= 2 or position()= 3]/div[1]/div[2]/ul/li[2]').text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="left"]/div[position()= 2 or position()= 3]/div[1]/div[2]/ul/li[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 46, in <module>
#     news_day,news= News18(link)
#   File "<ipython-input-50-a457a39ab5b3>", line 6, in News18
#     news_day = dri.find_element_by_xpath('//*[@id="left"]/div[position()= 2 or position()= 3]/div[1]/div[2]/ul/li[2]').text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="left"]/div[position()= 2 or position()= 3]/div[1]/div[2]/ul/li[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 46, in <module>
#     news_day,news= News18(link)
#   File "<ipython-input-50-a457a39ab5b3>", line 6, in News18
#     news_day = dri.find_element_by_xpath('//*[@id="left"]/div[position()= 2 or position()= 3]/div[1]/div[2]/ul/li[2]').text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="left"]/div[position()= 2 or position()= 3]/div[1]/div[2]/ul/li[2]"}
#   (Session info: chrome=89.0.4389.90)
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 48, in <module>
#     news_day,news= Bloomberg_Quint(link)
#   File "<ipython-input-51-5c0255772f00>", line 13, in Bloomberg_Quint
#     return news_day,news
# UnboundLocalError: local variable 'news_day' referenced before assignment
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 48, in <module>
#     news_day,news= Bloomberg_Quint(link)
#   File "<ipython-input-51-5c0255772f00>", line 13, in Bloomberg_Quint
#     return news_day,news
# UnboundLocalError: local variable 'news_day' referenced before assignment
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 48, in <module>
#     news_day,news= Bloomberg_Quint(link)
#   File "<ipython-input-51-5c0255772f00>", line 13, in Bloomberg_Quint
#     return news_day,news
# UnboundLocalError: local variable 'news_day' referenced before assignment
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 42, in <module>
#     news_day,news= India_Infoline(link)
#   File "<ipython-input-48-fac51f260503>", line 6, in India_Infoline
#     news_day = dri.find_element_by_xpath('//*[@class="card primary_contnent_bg story_card_temp"]/section/header/div/div/p/span').text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@class="card primary_contnent_bg story_card_temp"]/section/header/div/div/p/span"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 42, in <module>
#     news_day,news= India_Infoline(link)
#   File "<ipython-input-48-fac51f260503>", line 6, in India_Infoline
#     news_day = dri.find_element_by_xpath('//*[@class="card primary_contnent_bg story_card_temp"]/section/header/div/div/p/span').text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@class="card primary_contnent_bg story_card_temp"]/section/header/div/div/p/span"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 42, in <module>
#     news_day,news= India_Infoline(link)
#   File "<ipython-input-48-fac51f260503>", line 6, in India_Infoline
#     news_day = dri.find_element_by_xpath('//*[@class="card primary_contnent_bg story_card_temp"]/section/header/div/div/p/span').text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@class="card primary_contnent_bg story_card_temp"]/section/header/div/div/p/span"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# ...
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-43-c9d1bcffc0da>", line 6, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[5]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 9, in Moneycontrol
#     news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 394, in find_element_by_xpath
#     return self.find_element(by=By.XPATH, value=xpath)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 976, in find_element
#     return self.execute(Command.FIND_ELEMENT, {
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[contains(@id,'article')]/div[1]/div[2]"}
#   (Session info: chrome=89.0.4389.90)
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 30, in <module>
#     news_day,news= Business_Today(link)
#   File "<ipython-input-42-06c0605b768d>", line 3, in Business_Today
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 30, in <module>
#     news_day,news= Business_Today(link)
#   File "<ipython-input-42-06c0605b768d>", line 3, in Business_Today
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 30, in <module>
#     news_day,news= Business_Today(link)
#   File "<ipython-input-42-06c0605b768d>", line 3, in Business_Today
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 3, in Moneycontrol
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 3, in Moneycontrol
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 32, in <module>
#     news_day,news= Moneycontrol(link)
#   File "<ipython-input-43-c9d1bcffc0da>", line 3, in Moneycontrol
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 24, in <module>
#     news_day,news = Economic_Times(link)
#   File "<ipython-input-39-e7b9920124c3>", line 3, in Economic_Times
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 24, in <module>
#     news_day,news = Economic_Times(link)
#   File "<ipython-input-39-e7b9920124c3>", line 3, in Economic_Times
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 24, in <module>
#     news_day,news = Economic_Times(link)
#   File "<ipython-input-39-e7b9920124c3>", line 3, in Economic_Times
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 24, in <module>
#     news_day,news = Economic_Times(link)
#   File "<ipython-input-39-e7b9920124c3>", line 3, in Economic_Times
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 24, in <module>
#     news_day,news = Economic_Times(link)
#   File "<ipython-input-39-e7b9920124c3>", line 3, in Economic_Times
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
#
# ERROR:__main__:no such element Unable to locate element
# Traceback (most recent call last):
#   File "<ipython-input-57-8bb2c49ca65c>", line 24, in <module>
#     news_day,news = Economic_Times(link)
#   File "<ipython-input-39-e7b9920124c3>", line 3, in Economic_Times
#     dri.get(url)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 333, in get
#     self.execute(Command.GET, {'url': url})
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py", line 321, in execute
#     self.error_handler.check_response(response)
#   File "C:\Users\shankar\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py", line 242, in check_response
#     raise exception_class(message, screen, stacktrace)
# selenium.common.exceptions.WebDriverException: Message: unknown error: net::ERR_NAME_NOT_RESOLVED
#   (Session info: chrome=89.0.4389.90)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-8bb2c49ca65c> in <module>
#      17 news_data = []
#      18 for url in nwe_link.ele:
# ---> 19     headline = url.find_element_by_xpath(".//div[2]/h5/p").text
#      20     sours= url.find_element_by_xpath(".//div[2]/p/span[3]").text
#      21     link = url.get_property('href')
#
# AttributeError: 'float' object has no attribute 'find_element_by_xpath'

# %%
news_df= pd.DataFrame(news_data)
#details_df = pd.DataFrame(news_details)

# %%
news_df.head()
# Out:
#                                            headlines             sources  \
# 0  Sensex Sinks Over 400 Points in Early Trade; N...              News18
# 1  Indian equity markets sink 1% as covid cases s...            Livemint
# 2  Market down in early trade: IndusInd Bank, Mar...  Free Press Journal
# 3  Market Wrap, March 24: Here’s all that happene...   Business Standard
# 4  Sensex tumbles over 300 points in early trade;...  Free Press Journal
#
#                                                links  \
# 0  https://www.news18.com/news/business/sensex-si...
# 1  https://www.livemint.com/market/stock-market-n...
# 2  https://www.freepressjournal.in/business/marke...
# 3  https://www.business-standard.com/podcast/mark...
# 4  https://www.freepressjournal.in/business/sense...
#
#                                        date  \
# 0  LAST UPDATED:\nMARCH 25, 2021, 10:37 IST
# 1        Updated: 25 Mar 2021, 10:13 AM IST
# 2  : Thursday, March 25, 2021, 10:06 AM IST
# 3
# 4  : Wednesday, March 24, 2021, 9:54 AM IST
#
#                                           news_story
# 0  Equity benchmark Sensex dropped over 400 point...
# 1  Index heavyweights Infosys, Reliance Industrie...
# 2  Equity benchmark Sensex dropped over 400 point...
# 3
# 4  Mumbai: Equity benchmark Sensex dropped over 3...

# %%
miss_df.head(60)
# Out:
#                                               headlines            sources  \
# 3     Market Wrap, March 24: Here’s all that happene...  Business Standard
# 6     Market Ahead, March 24: Top factors that could...  Business Standard
# 7     RIL, banks drag Sensex 871 pts lower at 49,180...  Business Standard
# 9     Bank rally gives Sensex 280-pt lift to get pas...     Economic Times
# 15    Sensex stages 500-pt recovery, ends 87 pts low...     Economic Times
# 20    Decline in banks outweighs gains in IT, pharma...  Business Standard
# 37    Latest LIVE News: KKR to invest Rs 5,500 crore...     Economic Times
# 53    After decade-low in July, Reliance Industries ...  Business Standard
# 57    Market Wrap, September 15: Here’s all that hap...  Business Standard
# 72    Carlyle | Reliance Industries: Carlyle may tak...     Economic Times
# 77    Carlyle may take $2 billion stake in retail ar...  Business Standard
# 146      Future Retail slumps 5%; down 40% in September     Economic Times
# 193                    Don’t write off the Nifty top 10     Economic Times
# 204   Side-tracked by Jio Platforms? Tata Digital pl...     Economic Times
# 251   Market Wrap, August 25: Here’s all that happen...  Business Standard
# 319   Reliance Foundation to partner W-GDP, USAID to...  Business Standard
# 338   Market Wrap, August 10: Here’s all that happen...  Business Standard
# 389   If you don’t count Reliance, market is at 10,2...     Economic Times
# 420   Market Ahead, July 31: Top factors that could ...  Business Standard
# 421   Top headlines: RIL’s PBT dips 40%, battle to s...  Business Standard
avl_news_df
# Out:
#                                                  links
# 0    https://www.financialexpress.com/market/zerodh...
# 1    https://www.thehindubusinessline.com/companies...
# 2    https://www.news18.com/news/business/future-gr...
# 3    https://www.thehindubusinessline.com/companies...
# 4    https://www.businesstoday.in/markets/company-s...
# ..                                                 ...
# 938  https://www.businesstoday.in/markets/company-s...
# 939  https://economictimes.indiatimes.com/markets/s...
# 940  https://www.businesstoday.in/markets/company-s...
# 941  https://www.freepressjournal.in/business/sense...
# 942  https://www.hindustantimes.com/business-news/s...
#
# [943 rows x 1 columns]

# %%
news_df.to_csv(r'C:\Users\shankar\Desktop\projects\reliance_df_2.CSV',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0e19c32de091> in <module>
# ----> 1 news_df.to_csv(r'C:\Users\shankar\Desktop\projects\reliance_df_2.CSV',index=False)
#
# NameError: name 'news_df' is not defined

# %%
error_df= pd.DataFrame(Error_url)
#error_df.to_csv(r'C:\Users\shankar\Desktop\projects\reliance_df_error.CSV',index=False)

# %%
error_df.to_csv(r'C:\Users\shankar\Desktop\projects\reliance_df_error.CSV',index=False)
error_df
# Out:
#                                             headlines             sources  \
# 0   Business Insight | BPCL privatisation: Govt re...        Moneycontrol
# 1   Reliance Industries posts strong recovery in S...        Moneycontrol
# 2   Stocks To Watch: Reliance Industries Sterling ...     Bloomberg Quint
# 3   In an RIL-fired rally, Sensex, Nifty settle ne...            Livemint
# 4   Stocks To Watch: Reliance Industries, Indiabul...     Bloomberg Quint
# 5   ‘Make 2G a part of history’: Mukesh Ambani as ...            Livemint
# 6   3 Point Analysis | What will be the impact of ...        Moneycontrol
# 7   RIL AGM 2020 LIVE Updates: Jio Ready With Home...              News18
# 8   Sensex, Nifty End Little Changed; Reliance Ind...     Bloomberg Quint
# 9   RIL AGM 2020 LIVE Updates: Reliance Industries...        Moneycontrol
# 10  Reliance Industries becomes the first Indian c...      India Infoline
# 11  Stocks To Watch: Reliance Industries, SBI Life...     Bloomberg Quint
# 12  Stocks To Watch: DLF, Reliance Industries & Ul...     Bloomberg Quint
# 13  Stocks To Watch: Reliance Industries, Titan Co...     Bloomberg Quint
# 14  BIG STORY | 3 weeks, 3 deals: How Jio changed ...        Moneycontrol
# 15  Reliance Industries to consider rights issue, ...  Free Press Journal
# 16  Reliance starts using WhatsApp for grocery del...  Free Press Journal
# 17  Facebook’s Jio investment to help Reliance Ind...  Free Press Journal
# 18  RIL stocks surge as Facebook to invest in Jio ...  Free Press Journal
# 19  L&T announces Rs 150cr donation to PM-CARES Fu...        Moneycontrol
# 20  Reliance Industries fell 2.8 percent, while Ho...      Business Today
# 21  India on way to becoming 3rd richest country, ...        Moneycontrol
# 22  Eight of top 10 companies suffer Rs 1.35 lakh ...      Economic Times
# 23  RIL's Hathway and Den stake buys may hit broad...      Economic Times
#
#                                                 links
# 0   https://www.moneycontrol.com/news/eye-on-india...
# 1   https://www.moneycontrol.com/news/business/mon...
# 2   https://www.bloombergquint.com/in-the-news/sto...
# 3   https://www.livemint.com/market/stock-market-n...
# 4   https://www.bloombergquint.com/in-the-news/sto...
# 5   https://www.livemint.com/companies/people/-mak...
# 6   https://www.moneycontrol.com/news/business/3-p...
# 7   https://www.news18.com/news/business/ril-agm-2...
# 8   https://www.bloombergquint.com/in-the-news/sen...
# 9   https://www.moneycontrol.com/news/business/ril...
# 10  https://www.indiainfoline.com/article/news-top...
# 11  https://www.bloombergquint.com/in-the-news/sto...
# 12  https://www.bloombergquint.com/in-the-news/sto...
# 13  https://www.bloombergquint.com/in-the-news/sto...
# 14  https://www.moneycontrol.com/news/business/com...
# 15  https://www.freepressjournal.in/business/relia...
# 16  https://www.freepressjournal.in/business/relia...
# 17  https://www.freepressjournal.in/business/faceb...
# 18  https://www.freepressjournal.in/business/ril-s...
# 19  https://www.moneycontrol.com/news/business/lt-...
# 20  https://www.businesstoday.in/markets/company-s...
# 21  https://www.moneycontrol.com/news/business/ind...
# 22  https://economictimes.indiatimes.com/markets/s...
# 23  https://economictimes.indiatimes.com/markets/s...

# %%
error_df =

# %%
error_df.links[5]
# Out:
# 'https://www.thehindu.com/business/markets/sensex-rallies-over-300-pts-in-early-trade-reliance-ind-up-2/article32674755.ece'

# %%
def Economic_Times(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    dri.delete_all_cookies() 
    dri.refresh()
    sleep(randint(2,5))
    try:
        news = dri.find_element_by_xpath('//*[@class="pageContent flt"]/article/div[2]').text
        news_date = dri.find_element_by_xpath('//*[@class="dt contentwrapper"]/div/time').text
    except:
        try:
            news =  dri.find_element_by_xpath('//*[@class="pageContent flt"]/article/div[3]').text 
            news_date = dri.find_element_by_xpath('//*[@class="dt contentwrapper"]/div/time').text
        except:
            news_date = ' '
            news = ' '
    #dri.close()
    return news_date,news

# %%
dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
Economic_Times('https://economictimes.indiatimes.com/industry/services/retail/carlyle-may-take-2-billion-stake-in-retail-arm-of-reliance-industries-report/articleshow/78099741.cms')
# Out:
# ('Last Updated: Sep 14, 2020, 12:05 PM IST',
#  "BENGALURU: Private equity firm Carlyle Group is looking to invest up to $2 billion in Indian conglomerate Reliance Industries NSE 0.93 %' retail business, a financial daily reported on Monday, citing people aware of the development.\n\nThe deal, if finalized, would be Carlyle's biggest investment in an Indian company and would be its first in the country's retail sector, the paper reported.\n\nReliance and Carlyle did not immediately respond to Reuters' requests for comment.")

# %%
def Business_Standard(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(2,5)) 
    try:
        news_date = dri.find_element_by_xpath("//*[@class= 'last-update mT10']/p/span[2]").text
        news = dri.find_element_by_xpath('//*[@id="hpcontentbox"]/div[5]/div[1]/div/div[3]/span').text
    except:
        try:
            news_date = dri.find_element_by_xpath("//*[@class= 'last-update mT10']/p/span[2]").text
            news = dri.find_element_by_xpath('//*[@id="hpcontentbox"]/div[5]/div[1]/div/div[5]/span').text
        except:
            try:
                news_date = dri.find_element_by_xpath("//*[@class= 'last-update mT10']/p/span[2]").text
                news = dri.find_element_by_xpath("//*[@class= 'p-content']").text
            except:
                news_date = ' '
                news = ' '            
    #dri.close()
    #data ={'date':date,'news_story':news}
    return news_date,news

# %%
url = 'https://www.business-standard.com/podcast/markets/market-ahead-april-8-top-factors-that-could-guide-market-today-121040800207_1.html'
Business_Standard(url)
# Out:
# ('Last Updated at April 8, 2021 08:18 IST',
#  "Indian markets looked set to extend gains to the third consecutive day on Thursday, tracking cues from global peers, as SGX Nifty traded 75 points or 0.50% higher at 14,938 at around 7.25 am. However, the session could be marked by high volatility on account of weekly F&O expiry.\nBesides global cues, development on the Covid-19 front is likely to sway the market mood. Keeping in view the rising virus cases, Prime Minister Narendra Modi will interact with chief ministers of states today to discuss the Covid-19 situation and the ongoing vaccination drive which will be keenly tracked by market participants.\nMeanwhile, on the global market front, the S&P 500 and Dow closed slightly higher after minutes from the Federal Reserve’s latest meeting reiterated its commitment to keep interest rates low until the US economy makes a more secure recovery.\nThe Dow Jones Industrial Average rose 0.05%, the S&P 500 gained 0.15% and the Nasdaq Composite dropped 0.07%.\nMost Asian equities tracked Wall Street's cautious gains and were up marginally. Australia’s S&P/ASX 200 Index rose 0.7%, Hong Kong's Hang Seng index added 0.43% while Japan's Nikkie 225 index shed 0.43%.\nNow, a look at the stock-specific triggers that are likely to guide the market today:\nShares of Reliance Industries will be in focus today after Sebi imposed a total penalty of Rs 25 crore on Mukesh Ambani, Anil Ambani, other individuals and entities for non-compliance with takeover norms in a Reliance Industries case dating back to 2000.\nAnil Agarwal-led Vedanta Resources Ltd's sweetened offer to buy back 17.5 per cent share in its Indian flagship firm was subscribed 57.5 per cent, helping it raise its stake to about 65 per cent. If the maximum 651 million shares would have got tendered the promoter stake would have increased to72.6 per cent.\nUCO Bank on Wednesday said its board has approved allotment of preference shares to the government for infusing Rs 2,600 crore capital.\nMuthoot Finance is planning to raise Rs 1,700 crore through public issue of secured redeemable non-convertible debentures. The issue opens on April 8 and will close on April 29.\nLastly, an update on the primary market. The initial public offer of Macrotech Developers was subscribed 26 per cent on the first day of subscription on Wednesday. The category for qualified institutional buyers was subscribed 58 per cent, non-institutional investors 11 per cent and retail individual investors 15 per cent.")

# %%
def Hindu_Businessline(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(2,5)) 
    #head = dri.find_element_by_class_name('title-bor-bottom').text
    news_date = dri.find_element_by_xpath("//*[@class ='update-date']/none").text
    news = dri.find_element_by_xpath('//*[@id="ControlPara"]/div[1]').text
    #dri.close()
    return news_date,news

# %%
def Business_Today(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,4)) 
    #head = dri.find_element_by_class_name('headline').text
    news_day = dri.find_element_by_xpath('//*[@class="story-details"]').text
    news =     dri.find_element_by_xpath('//*[@class="story-right relatedstory paywall"]').text
    #dri.close()
    return news_day,news

# %%
def Moneycontrol(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    try:
        news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[5]/div[2]").text
        news = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[3]").text
    except:
        news_date = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[1]/div[2]").text
        news = dri.find_element_by_xpath("//*[contains(@id,'article')]/div[3]").text
    #dri.close()
    return news_date,news

# %%
def Free_Press_Journal(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    date = dri.find_element_by_xpath("//*[@id='container']/div/div[1]/div/div[1]/div[1]/div[1]/div[1]/time").text
    news = dri.find_element_by_xpath('//*[@id="container"]/div/div[1]/div/div[1]/div[1]/div[5]/div[2]/div[2]/div/div[1]/div[1]/div[1]/div/div').text
    #dri.close()
    #data ={'date':date,'news_story':news}
    return date,news

# %%
def Livemint(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    dri.delete_all_cookies() 
    dri.refresh()
    sleep(randint(1,3))
    news_day = dri.find_element_by_xpath("//*[contains(@id,'tBox')]").text
    news_1 = dri.find_element_by_xpath("//*[contains(@id,'summary')]").text
    news_2 = dri.find_element_by_xpath("//*[contains(@id,'mainArea')]/div[1]").text
    news_3 = dri.find_element_by_xpath("//*[contains(@id,'mainArea')]/div[2]").text
    news = " ".join([news_1, news_2,news_3]) 
    #dri.close()
    return news_day,news

# %%
def Financial_Express(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    news_day = dri.find_element_by_xpath('//*[@class="storybox" or @class="story_mid"]/div/div/div/span').text 
    try:
        news = dri.find_element_by_xpath('//*[@id="main-story-1"]/div/div[1]/div[2]/div/div[2]').text
    except:
        news = dri.find_element_by_xpath("//*[@class='storybox']/div[2]/div").text
    #dri.close()
    return news_day,news

# %%
def India_Infoline(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    #head = dri.find_element_by_xpath('//*[@class="card primary_contnent_bg story_card_temp"]/section/header/h2').text
    news_day = dri.find_element_by_xpath('//*[@class="card primary_contnent_bg story_card_temp"]/section/header/div/div/p/span').text
    news = dri.find_element_by_xpath('//*[@id="story_card"]/div[2]').text
    #dri.close()
    return news_day,news

# %%
def Firstpost(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    #head = dri.find_element_by_xpath('//*[@id="headlineitem"]').text
    news_day= dri.find_element_by_xpath('//*[@class="author-info"]/span').text
    news = dri.find_element_by_xpath('//*[@class="inner-copy article-full-content"]').text
    #dri.close()
    return news_day,news

# %%
def News18(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    #head = dri.find_element_by_xpath('//*[@id="left"]/div[3]/h1').text
    news_day = dri.find_element_by_xpath('//*[@id="left"]/div[position()= 2 or position()= 3]/div[1]/div[2]/ul/li[2]').text
    news = dri.find_element_by_xpath('//*[@id="left"]/div[position()= 2 or position()= 3]/article').text
    #dri.close()
    return news_day,news

# %%
def Bloomberg_Quint(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    try:
        #head = dri.find_element_by_xpath("//*[contains(@class,'container story-base-template')]/section/div[1]/h1").text
        news_day = dri.find_element_by_xpath("//*[contains(@class,'container story-base-template')]/section/div[1]/div[2]/div/time").text
        news = dri.find_element_by_xpath("//*[contains(@id,'piano-content-controller')]").text
    except:
        news_date = ' '
        news = ' '
    #dri.close()
    return news_day,news

# %%
def The_Hindu(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    #head = dri.find_element_by_xpath("//*[@class='article']/div/h1").text
    news_day= dri.find_element_by_xpath("//*[@class='article']/div/div[2]/div/div/span").text
    news = dri.find_element_by_xpath("//*[contains(@id,'content-body')]").text
    #dri.close()
    return news_day,news

# %%
  def Investing_com(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    try:
        head = dri.find_element_by_tag_name("article")
        #headline= head.find_element_by_class_name('article-item-title').text
        #headline = head.find_element_by_xpath("//header/h1").text
        news_date=    head.find_element_by_xpath("//header/footer").text
        news =        head.find_element_by_class_name('article-item-content-wrapper').text
    except:
        news_date = ' '
        news = ' '
    #dri.close()
    return news_date,news

# %%
def Reuters(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    #head = dri.find_element_by_xpath('//*[@id="__next"]/div/div[3]/div[2]/div/div/h1').text
    raw_data = dri.find_element_by_class_name('ArticleHeader-date-line-3oc3Y')
    day =  raw_data.find_element_by_xpath('//time[1]').text
    time =  raw_data.find_element_by_xpath('//time[2]').text
    data = " ".join([day,time])     
    news = dri.find_element_by_class_name('ArticleBodyWrapper').text 
    #dri.close()
    return data,news

# %%
def Hindustan_Times(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    #head = dri.find_element_by_xpath("//*[@id='dataHolder']/div[1]/div[1]/h1").text
    date = dri.find_element_by_xpath("//*[@id='dataHolder']/div[1]/div[1]/div[4]/div[2]").text
    news = dri.find_element_by_xpath("//*[@class='detail']").text
    #dri.close()
    return date,news

# %%
def zeenews(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    #dri.delete_all_cookies() 
    sleep(randint(2,5))
    dri.find_element_by_xpath('//*[@class="tbl-read-more-box"]/a').click()
    try:
        news_date = dri.find_element_by_xpath("//*[@class = 'article-share-block margin-bt30px inner static']/div[6]").text
    except:
        news_date = dri.find_element_by_xpath("//*[@class = 'article-share-block margin-bt30px inner static']/div[5]").text
    news = dri.find_elements_by_xpath('//*[@class="field-items"]/div')[-1].text
    return news_date,news

# %%
def Indian_Express(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    #dri.delete_all_cookies() 
    sleep(randint(2,5))
    try:
        news_date = dri.find_element_by_xpath('//*[@id="storycenterbyline"]/span').text
        news_div = dri.find_elements_by_xpath("//*[@id='pcl-full-content']/p")
        news = []
        x = [news.append(i.text) for i in news_div]
        news = ' '.join(news)
    except:
        news_date = dri.find_element_by_xpath('//*[@class="ie-authorbox"]/div/span').text
        news_div = dri.find_elements_by_xpath('//*[@class="articles"]/div/p')
        news = []
        x = [news.append(i.text) for i in news_div]
        news = ' '.join(news)
    return news_date,news

# %%
def aninews(url):
    #dri= webdriver.Chrome(executable_path=drive_path,options=chrome_options)
    dri.get(url)
    sleep(randint(1,3))
    #head = dri.find_element_by_xpath("//*[@id='dataHolder']/div[1]/div[1]/h1").text
    date = dri.find_element_by_xpath("//*[@id='news-detail-block']/div[1]/article/div/p/span[2]").text
    news = dri.find_element_by_xpath("//*[@id='news-detail-block']/div[1]/article/div[2]").text
    #dri.close()
    return date,news

# %%
aninews('https://www.aninews.in/news/business/mukesh-ambani-shows-interest-to-invest-in-himachal-pradesh20190628170556/')
# Out:
# ('Jun 28, 2019 17:07',
#  'Mumbai (Maharashtra) [India], June 28 (ANI): Himachal Pradesh Chief Minister Jai Ram Thakur met Chairman of Reliance Industries Mukesh Ambani as part of an outreach activity for attracting investments to the state.\nThakur invited Reliance to participate in the maiden global investors meet being organised by the state government at Dharmashala during November.\nThakur said the state government provides all basic facilities to potential entrepreneurs including availability of land, uninterrupted electricity supply and a responsive administration.\nAmbani offered to strengthen the Jio broadband network, particularly in rural areas, by laying new optical fibre lines. He also showed interest in post-harvest management of fruit and vegetable besides setting up a mobile phone assembly unit in Baddi, Barotiwala and Nalagarh area.\nA team of company officials will visit the state soon to finalise these activities. Ambani also expressed desire to set up a resort in Dharamshala.\nThose accompanying Thakur on Thursday were state Industries Minister Bikram Singh, Additional Chief Secretaries Shrikant Baldi, Ram Subhag Singh and Manoj Kumar, Principal Secretary Prabodh Saxena, Director Industries Hans Raj Sharma, Special Secretary Abid Hussain Sadiq and Principal Private Secretary to the Chief Minister Vinay Singh. (ANI)')
